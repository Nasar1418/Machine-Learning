# %% [markdown]
# Command to know about Ram

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: AuthenticAMD
# cpu family	: 23
# model		: 49
# model name	: AMD EPYC 7B12
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2249.998
# cache size	: 512 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ht syscall nx mmxext fxsr_opt pdpe1gb rdtscp lm constant_tsc rep_good nopl nonstop_tsc cpuid extd_apicid tsc_known_freq pni pclmulqdq ssse3 fma cx16 sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm cmp_legacy cr8_legacy abm sse4a misalignsse 3dnowprefetch osvw topoext ssbd ibrs ibpb stibp vmmcall fsgsbase tsc_adjust bmi1 avx2 smep bmi2 rdseed adx smap clflushopt clwb sha_ni xsaveopt xsavec xgetbv1 clzero xsaveerptr arat npt nrip_save umip rdpid
# ...

# %% [markdown]
# **Command to Know about memory**

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13290460 kB
# MemFree:         8540500 kB
# MemAvailable:   12086252 kB
# Buffers:          395428 kB
# Cached:          3296804 kB
# SwapCached:            0 kB
# Active:           771600 kB
# Inactive:        3632820 kB
# Active(anon):       1284 kB
# Inactive(anon):   712512 kB
# Active(file):     770316 kB
# Inactive(file):  2920308 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               104 kB
# Writeback:            92 kB
# AnonPages:        712192 kB
# Mapped:           327184 kB
# Shmem:              1600 kB
# KReclaimable:     180532 kB
# Slab:             223696 kB
# SReclaimable:     180532 kB
# SUnreclaim:        43164 kB
# KernelStack:        5912 kB
# PageTables:        10828 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6645228 kB
# Committed_AS:    3056616 kB
# ...

# %%
# !pip install pandas

# %%
import pandas as pd

df=pd.read_csv('/content/Car.csv')
df.head()
# Out:
#    Price_in_thousands  Engine_size  Horsepower  Fuel_efficiency   sales
# 0               21.50          1.8       140.0             28.0  16.919
# 1               28.40          3.2       225.0             25.0  39.384
# 2                 NaN          3.2       225.0             26.0  14.114
# 3               42.00          3.5       210.0             22.0   8.588
# 4               23.99          1.8       150.0             27.0  20.397

# %%
print("Machine Learning")
# Out:
# Machine Learning

# %%
# !ls
# Out:
# Car.csv  sample_data
